# %%
import os
import sys
import gym
import random
import numpy as np
import matplotlib.pyplot as plt 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from collections import namedtuple, deque

# %% [markdown]
# ## utils

# %%
Transition = namedtuple('Transition', ('state', 'next_state', 'action', 'reward', 'mask'))


class Memory(object):
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)
        self.capacity = capacity

    def push(self, state, next_state, action, reward, mask):
        self.memory.append(Transition(state, next_state, action, reward, mask))

    def sample(self, batch_size):
        transitions = random.sample(self.memory, batch_size)
        batch = Transition(*zip(*transitions))
        return batch

    def __len__(self):
        return len(self.memory)

# %%
def get_action(state, online_net, epsilon, env):
    if np.random.rand() <= epsilon:
        return env.action_space.sample()
    else:
        return online_net.get_action(state)

def update_target_model(online_net, target_net):
    target_net.load_state_dict(online_net.state_dict())

# %% [markdown]
# ## DQN

# %%
class QNet(nn.Module):
    def __init__(self, num_inputs, num_outputs):
        super(QNet, self).__init__()
        self.num_inputs = num_inputs
        self.num_outputs = num_outputs

        self.fc1 = nn.Linear(num_inputs, 128)
        self.fc2 = nn.Linear(128, num_outputs)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        qvalue = self.fc2(x)
        return qvalue

    @classmethod
    def train_model(cls, online_net, target_net, optimizer, batch):
        states = torch.stack(batch.state)
        next_states = torch.stack(batch.next_state)
        actions = torch.Tensor(batch.action).float().to(device)
        rewards = torch.Tensor(batch.reward).to(device)
        masks = torch.Tensor(batch.mask).to(device)

        pred = online_net(states).squeeze(1)
        next_pred = target_net(next_states).squeeze(1)

        pred = torch.sum(pred.mul(actions), dim=1)

        target = rewards + masks * gamma * next_pred.max(1)[0]

        loss = F.mse_loss(pred, target.detach())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        return loss

    def get_action(self, input):
        qvalue = self.forward(input)
        _, action = torch.max(qvalue, 1)
        return action[0].item()

# %% [markdown]
# ###  hyper parameters

# %%
gamma = 0.999
batch_size = 64
lr = 0.001
log_interval = 10
update_target = 100
replay_memory_capacity = 1000
count_epsds = 2000
epsilon = 1.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ##### train

# %%
env_name = 'CartPole-v1'

env = gym.make(env_name)
env.seed(0)
torch.manual_seed(0)

num_inputs = env.observation_space.shape[0]
num_actions = env.action_space.n

online_net = QNet(num_inputs, num_actions)
target_net = QNet(num_inputs, num_actions)
update_target_model(online_net, target_net)

optimizer = optim.Adam(online_net.parameters(), lr=lr)

online_net.to(device)
target_net.to(device)
online_net.train()
target_net.train()
memory = Memory(replay_memory_capacity)

steps = 0
loss = 0
nbr_actions_list, score_list, loss_list = [],[],[]

for e in range(count_epsds):
    
    done = False
    score = 0
    state = env.reset()
    state = torch.Tensor(state).to(device)
    state = state.unsqueeze(0)
    nbr_actions = 0
    avg_loss = 0 
    while not done:
        steps += 1

        
        action = get_action(state, online_net, epsilon, env)
        next_state, reward, done, _ = env.step(action)
        nbr_actions += 1
        next_state = torch.Tensor(next_state).to(device)
        next_state = next_state.unsqueeze(0)

        mask = 0 if done else 1
        reward = reward if not done or score == 499 else -1
        action_one_hot = np.zeros( 2 )
        action_one_hot[action] = 1
        memory.push(state, next_state, action_one_hot, reward, mask)

        score += reward
        state = next_state

        if steps > replay_memory_capacity:
            epsilon -= 0.00005
            epsilon = max(epsilon, 0.05)

            batch = memory.sample(batch_size)
            loss = QNet.train_model(online_net, target_net, optimizer, batch)

            if steps % update_target == 0:
                update_target_model(online_net, target_net)

            
            avg_loss += loss
    
    nbr_actions_list.append(nbr_actions)
    score_list.append(score)
    loss_list.append(float(avg_loss)/nbr_actions)
    
    
    if e % log_interval == 0:
        print('episode {}| nbr_actions: {} | epsilon: {:.2f}'.format(
            e, nbr_actions, epsilon))
# Out:
# episode 0| nbr_actions: 20 | epsilon: 1.00
# episode 10| nbr_actions: 14 | epsilon: 1.00
# episode 20| nbr_actions: 47 | epsilon: 1.00
# episode 30| nbr_actions: 20 | epsilon: 1.00
# episode 40| nbr_actions: 34 | epsilon: 1.00
# episode 50| nbr_actions: 11 | epsilon: 1.00
# episode 60| nbr_actions: 32 | epsilon: 0.99
# episode 70| nbr_actions: 22 | epsilon: 0.97
# episode 80| nbr_actions: 18 | epsilon: 0.96
# episode 90| nbr_actions: 32 | epsilon: 0.94
# episode 100| nbr_actions: 29 | epsilon: 0.92
# episode 110| nbr_actions: 19 | epsilon: 0.91
# episode 120| nbr_actions: 15 | epsilon: 0.90
# episode 130| nbr_actions: 29 | epsilon: 0.89
# episode 140| nbr_actions: 17 | epsilon: 0.87
# episode 150| nbr_actions: 17 | epsilon: 0.86
# episode 160| nbr_actions: 21 | epsilon: 0.84
# episode 170| nbr_actions: 24 | epsilon: 0.83
# episode 180| nbr_actions: 48 | epsilon: 0.81
# episode 190| nbr_actions: 124 | epsilon: 0.78
# episode 200| nbr_actions: 81 | epsilon: 0.75
# episode 210| nbr_actions: 159 | epsilon: 0.72
# episode 220| nbr_actions: 41 | epsilon: 0.70
# episode 230| nbr_actions: 96 | epsilon: 0.67
# episode 240| nbr_actions: 19 | epsilon: 0.64
# episode 250| nbr_actions: 28 | epsilon: 0.60
# episode 260| nbr_actions: 168 | epsilon: 0.52
# episode 270| nbr_actions: 192 | epsilon: 0.47
# episode 280| nbr_actions: 334 | epsilon: 0.34
# episode 290| nbr_actions: 274 | epsilon: 0.19
# episode 300| nbr_actions: 240 | epsilon: 0.07
# episode 310| nbr_actions: 202 | epsilon: 0.05
# episode 320| nbr_actions: 251 | epsilon: 0.05
# episode 330| nbr_actions: 358 | epsilon: 0.05
# episode 340| nbr_actions: 478 | epsilon: 0.05
# episode 350| nbr_actions: 500 | epsilon: 0.05
# episode 360| nbr_actions: 338 | epsilon: 0.05
# episode 370| nbr_actions: 500 | epsilon: 0.05
# episode 380| nbr_actions: 500 | epsilon: 0.05
# episode 390| nbr_actions: 500 | epsilon: 0.05
# episode 400| nbr_actions: 500 | epsilon: 0.05
# episode 410| nbr_actions: 160 | epsilon: 0.05
# episode 420| nbr_actions: 172 | epsilon: 0.05
# episode 430| nbr_actions: 136 | epsilon: 0.05
# episode 440| nbr_actions: 152 | epsilon: 0.05
# episode 450| nbr_actions: 198 | epsilon: 0.05
# episode 460| nbr_actions: 211 | epsilon: 0.05
# episode 470| nbr_actions: 500 | epsilon: 0.05
# episode 480| nbr_actions: 500 | epsilon: 0.05
# episode 490| nbr_actions: 500 | epsilon: 0.05
# episode 500| nbr_actions: 500 | epsilon: 0.05
# episode 510| nbr_actions: 500 | epsilon: 0.05
# episode 520| nbr_actions: 500 | epsilon: 0.05
# episode 530| nbr_actions: 500 | epsilon: 0.05
# episode 540| nbr_actions: 500 | epsilon: 0.05
# episode 550| nbr_actions: 500 | epsilon: 0.05
# episode 560| nbr_actions: 500 | epsilon: 0.05
# episode 570| nbr_actions: 500 | epsilon: 0.05
# episode 580| nbr_actions: 126 | epsilon: 0.05
# episode 590| nbr_actions: 500 | epsilon: 0.05
# episode 600| nbr_actions: 173 | epsilon: 0.05
# episode 610| nbr_actions: 138 | epsilon: 0.05
# episode 620| nbr_actions: 188 | epsilon: 0.05
# episode 630| nbr_actions: 387 | epsilon: 0.05
# episode 640| nbr_actions: 500 | epsilon: 0.05
# episode 650| nbr_actions: 500 | epsilon: 0.05
# episode 660| nbr_actions: 83 | epsilon: 0.05
# episode 670| nbr_actions: 500 | epsilon: 0.05
# episode 680| nbr_actions: 500 | epsilon: 0.05
# episode 690| nbr_actions: 154 | epsilon: 0.05
# episode 700| nbr_actions: 9 | epsilon: 0.05
# episode 710| nbr_actions: 500 | epsilon: 0.05
# episode 720| nbr_actions: 500 | epsilon: 0.05
# episode 730| nbr_actions: 500 | epsilon: 0.05
# episode 740| nbr_actions: 500 | epsilon: 0.05
# episode 750| nbr_actions: 500 | epsilon: 0.05
# episode 760| nbr_actions: 500 | epsilon: 0.05
# episode 770| nbr_actions: 500 | epsilon: 0.05
# episode 780| nbr_actions: 100 | epsilon: 0.05
# episode 790| nbr_actions: 30 | epsilon: 0.05
# episode 800| nbr_actions: 51 | epsilon: 0.05
# episode 810| nbr_actions: 56 | epsilon: 0.05
# episode 820| nbr_actions: 87 | epsilon: 0.05
# episode 830| nbr_actions: 125 | epsilon: 0.05
# episode 840| nbr_actions: 500 | epsilon: 0.05
# episode 850| nbr_actions: 500 | epsilon: 0.05
# episode 860| nbr_actions: 500 | epsilon: 0.05
# episode 870| nbr_actions: 500 | epsilon: 0.05
# episode 880| nbr_actions: 500 | epsilon: 0.05
# episode 890| nbr_actions: 500 | epsilon: 0.05
# episode 900| nbr_actions: 500 | epsilon: 0.05
# episode 910| nbr_actions: 500 | epsilon: 0.05
# episode 920| nbr_actions: 500 | epsilon: 0.05
# episode 930| nbr_actions: 500 | epsilon: 0.05
# episode 940| nbr_actions: 500 | epsilon: 0.05
# episode 950| nbr_actions: 500 | epsilon: 0.05
# episode 960| nbr_actions: 141 | epsilon: 0.05
# episode 970| nbr_actions: 112 | epsilon: 0.05
# episode 980| nbr_actions: 258 | epsilon: 0.05
# episode 990| nbr_actions: 500 | epsilon: 0.05
# episode 1000| nbr_actions: 9 | epsilon: 0.05
# episode 1010| nbr_actions: 240 | epsilon: 0.05
# episode 1020| nbr_actions: 500 | epsilon: 0.05
# episode 1030| nbr_actions: 109 | epsilon: 0.05
# episode 1040| nbr_actions: 77 | epsilon: 0.05
# episode 1050| nbr_actions: 112 | epsilon: 0.05
# episode 1060| nbr_actions: 500 | epsilon: 0.05
# episode 1070| nbr_actions: 500 | epsilon: 0.05
# episode 1080| nbr_actions: 500 | epsilon: 0.05
# episode 1090| nbr_actions: 500 | epsilon: 0.05
# episode 1100| nbr_actions: 500 | epsilon: 0.05
# episode 1110| nbr_actions: 500 | epsilon: 0.05
# episode 1120| nbr_actions: 500 | epsilon: 0.05
# episode 1130| nbr_actions: 500 | epsilon: 0.05
# episode 1140| nbr_actions: 500 | epsilon: 0.05
# episode 1150| nbr_actions: 500 | epsilon: 0.05
# episode 1160| nbr_actions: 500 | epsilon: 0.05
# episode 1170| nbr_actions: 237 | epsilon: 0.05
# episode 1180| nbr_actions: 500 | epsilon: 0.05
# episode 1190| nbr_actions: 500 | epsilon: 0.05
# episode 1200| nbr_actions: 500 | epsilon: 0.05
# episode 1210| nbr_actions: 500 | epsilon: 0.05
# episode 1220| nbr_actions: 500 | epsilon: 0.05
# episode 1230| nbr_actions: 500 | epsilon: 0.05
# episode 1240| nbr_actions: 500 | epsilon: 0.05
# episode 1250| nbr_actions: 500 | epsilon: 0.05
# episode 1260| nbr_actions: 500 | epsilon: 0.05
# episode 1270| nbr_actions: 500 | epsilon: 0.05
# episode 1280| nbr_actions: 500 | epsilon: 0.05
# episode 1290| nbr_actions: 500 | epsilon: 0.05
# episode 1300| nbr_actions: 500 | epsilon: 0.05
# episode 1310| nbr_actions: 500 | epsilon: 0.05
# episode 1320| nbr_actions: 500 | epsilon: 0.05
# episode 1330| nbr_actions: 500 | epsilon: 0.05
# episode 1340| nbr_actions: 10 | epsilon: 0.05
# episode 1350| nbr_actions: 500 | epsilon: 0.05
# episode 1360| nbr_actions: 500 | epsilon: 0.05
# episode 1370| nbr_actions: 500 | epsilon: 0.05
# episode 1380| nbr_actions: 500 | epsilon: 0.05
# episode 1390| nbr_actions: 135 | epsilon: 0.05
# episode 1400| nbr_actions: 134 | epsilon: 0.05
# episode 1410| nbr_actions: 138 | epsilon: 0.05
# episode 1420| nbr_actions: 128 | epsilon: 0.05
# episode 1430| nbr_actions: 135 | epsilon: 0.05
# episode 1440| nbr_actions: 152 | epsilon: 0.05
# episode 1450| nbr_actions: 179 | epsilon: 0.05
# episode 1460| nbr_actions: 500 | epsilon: 0.05
# episode 1470| nbr_actions: 282 | epsilon: 0.05
# episode 1480| nbr_actions: 500 | epsilon: 0.05
# episode 1490| nbr_actions: 500 | epsilon: 0.05
# episode 1500| nbr_actions: 233 | epsilon: 0.05
# episode 1510| nbr_actions: 208 | epsilon: 0.05
# episode 1520| nbr_actions: 329 | epsilon: 0.05
# episode 1530| nbr_actions: 255 | epsilon: 0.05
# episode 1540| nbr_actions: 500 | epsilon: 0.05
# episode 1550| nbr_actions: 500 | epsilon: 0.05
# episode 1560| nbr_actions: 500 | epsilon: 0.05
# episode 1570| nbr_actions: 500 | epsilon: 0.05
# episode 1580| nbr_actions: 12 | epsilon: 0.05
# episode 1590| nbr_actions: 195 | epsilon: 0.05
# episode 1600| nbr_actions: 168 | epsilon: 0.05
# episode 1610| nbr_actions: 222 | epsilon: 0.05
# episode 1620| nbr_actions: 188 | epsilon: 0.05
# episode 1630| nbr_actions: 333 | epsilon: 0.05
# episode 1640| nbr_actions: 500 | epsilon: 0.05
# episode 1650| nbr_actions: 500 | epsilon: 0.05
# episode 1660| nbr_actions: 500 | epsilon: 0.05
# episode 1670| nbr_actions: 298 | epsilon: 0.05
# episode 1680| nbr_actions: 182 | epsilon: 0.05
# episode 1690| nbr_actions: 162 | epsilon: 0.05
# episode 1700| nbr_actions: 160 | epsilon: 0.05
# episode 1710| nbr_actions: 163 | epsilon: 0.05
# episode 1720| nbr_actions: 174 | epsilon: 0.05
# episode 1730| nbr_actions: 213 | epsilon: 0.05
# episode 1740| nbr_actions: 269 | epsilon: 0.05
# episode 1750| nbr_actions: 208 | epsilon: 0.05
# episode 1760| nbr_actions: 185 | epsilon: 0.05
# episode 1770| nbr_actions: 121 | epsilon: 0.05
# episode 1780| nbr_actions: 146 | epsilon: 0.05
# episode 1790| nbr_actions: 130 | epsilon: 0.05
# episode 1800| nbr_actions: 205 | epsilon: 0.05
# episode 1810| nbr_actions: 500 | epsilon: 0.05
# episode 1820| nbr_actions: 500 | epsilon: 0.05
# episode 1830| nbr_actions: 500 | epsilon: 0.05
# episode 1840| nbr_actions: 500 | epsilon: 0.05
# episode 1850| nbr_actions: 79 | epsilon: 0.05
# episode 1860| nbr_actions: 500 | epsilon: 0.05
# episode 1870| nbr_actions: 104 | epsilon: 0.05
# episode 1880| nbr_actions: 500 | epsilon: 0.05
# episode 1890| nbr_actions: 500 | epsilon: 0.05
# episode 1900| nbr_actions: 500 | epsilon: 0.05
# episode 1910| nbr_actions: 500 | epsilon: 0.05
# episode 1920| nbr_actions: 500 | epsilon: 0.05
# episode 1930| nbr_actions: 500 | epsilon: 0.05
# episode 1940| nbr_actions: 500 | epsilon: 0.05
# episode 1950| nbr_actions: 343 | epsilon: 0.05
# episode 1960| nbr_actions: 500 | epsilon: 0.05
# episode 1970| nbr_actions: 500 | epsilon: 0.05
# episode 1980| nbr_actions: 500 | epsilon: 0.05
# episode 1990| nbr_actions: 500 | epsilon: 0.05

# %%
plt.figure(figsize=(14,5))
    


plt.subplot(1,2,1)
plt.plot( np.arange(count_epsds), nbr_actions_list, "g")
plt.xlabel('episodes')
plt.title("nbr_actions")

plt.subplot(1,2,2)
plt.plot( np.arange(count_epsds), loss_list)
plt.xlabel('episodes')
plt.title("DQN Q approximator loss")


plt.show()

# %%
# %matplotlib inline

import pandas as pd 

smoothed_rewards = pd.Series.rolling(pd.Series(nbr_actions_list), 100).mean()
smoothed_rewards = [elem for elem in smoothed_rewards]


plt.figure(figsize=(14, 5))

plt.subplot(1,2,1)
plt.plot(nbr_actions_list)
plt.title("normal plot")
plt.xlabel("episodes")
plt.ylabel("nbr actions")

plt.subplot(1,2,2)
plt.plot(smoothed_rewards ,"r")
plt.title("Smooth plot")
plt.xlabel("episodes")
plt.ylabel("nbr actions")

plt.show()
